# %%
import xarray as xr
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy

# %%
draw= numpy.random.normal(scale = 1.5,size = 30)
print (draw)
# Out:
# [-0.85818114 -1.10679481 -0.51249429 -2.38904099  1.00098154 -2.24335802
#  -0.03857907  0.18463856  2.25592603 -0.61539167  4.0076184  -1.04499565
#   2.0327232   0.62016313 -0.53722604 -1.5760382   1.17733347 -0.66842627
#  -2.43879057 -1.34119309 -0.09485775 -2.03793083 -1.50285436 -1.71000649
#   1.7294925  -0.08138422  1.09264599 -2.31402508 -0.50926953  0.57970095]

# %%
plt.scatter(numpy.arange(0,30),abs(draw+4.1))
new_draw = abs(draw+4.1)/10
print(new_draw)
# Out:
# [0.32418189 0.29932052 0.35875057 0.1710959  0.51009815 0.1856642
#  0.40614209 0.42846386 0.6355926  0.34846083 0.81076184 0.30550044
#  0.61327232 0.47201631 0.3562774  0.25239618 0.52773335 0.34315737
#  0.16612094 0.27588069 0.40051422 0.20620692 0.25971456 0.23899935
#  0.58294925 0.40186158 0.5192646  0.17859749 0.35907305 0.4679701 ]

# %%
sorted_draw = sorted(new_draw)
plt.plot(sorted_draw)

# %%
trial_branch = xr.open_dataset("/glade/scratch/mollyw/archive/restart19/ice/hist/restart19.cice.h.0043-01.nc")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/pkg-library/20200417/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     197             try:
# --> 198                 file = self._cache[self._key]
#     199             except KeyError:
#
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/pkg-library/20200417/lib/python3.7/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/glade/scratch/mollyw/archive/restart19/ice/hist/restart19.cice.h.0043-01.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# ...

# %%
trial_hybrid = xr.open_dataset("/glade/scratch/mollyw/archive/restart19_hybrid/ice/hist/restart19_hybrid.cice.h.2000-01.nc")

# %%
trial_branch
# Out:
# <xarray.Dataset>
# Dimensions:      (d2: 2, nc: 5, ni: 320, nj: 384, nkbio: 5, nkice: 8, nksnow: 3, nvertices: 4, time: 1)
# Coordinates:
#   * time         (time) object 0043-02-01 00:00:00
#     TLON         (nj, ni) float32 ...
#     TLAT         (nj, ni) float32 ...
#     ULON         (nj, ni) float32 ...
#     ULAT         (nj, ni) float32 ...
#     NCAT         (nc) float32 ...
# Dimensions without coordinates: d2, nc, ni, nj, nkbio, nkice, nksnow, nvertices
# Data variables:
#     time_bounds  (time, d2) object ...
#     VGRDi        (nkice) float32 ...
#     VGRDs        (nksnow) float32 ...
#     VGRDb        (nkbio) float32 ...
#     tmask        (nj, ni) float32 ...
#     tarea        (nj, ni) float32 ...
#     uarea        (nj, ni) float32 ...
#     dxt          (nj, ni) float32 ...
#     dyt          (nj, ni) float32 ...
#     dxu          (nj, ni) float32 ...
#     dyu          (nj, ni) float32 ...
#     HTN          (nj, ni) float32 ...
# ...

# %%
imshow(trial_branch.aice)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-672c69273b9f> in <module>
# ----> 1 imshow(trial_branch.aice)
#
# NameError: name 'imshow' is not defined
